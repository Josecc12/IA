# %% [markdown]
# ###  1.Linear Regression

# %%
import numpy as np
import seaborn as sns
import scipy as stats
import statsmodels.api as sm

# %%
auto = sns.load_dataset('mpg')

# %%
auto
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name
# 0            70     usa  chevrolet chevelle malibu
# ...

# %% [markdown]
# ### 1.1 Regression Model
# y=mx+b

# %%
x= auto['weight']
x = sm.add_constant(x)
y = auto ['mpg']

# %%
result = sm.OLS(y,x).fit()

# %%
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                    mpg   R-squared:                       0.692
# Model:                            OLS   Adj. R-squared:                  0.691
# Method:                 Least Squares   F-statistic:                     888.9
# Date:                Wed, 01 Feb 2023   Prob (F-statistic):          2.97e-103
# Time:                        08:42:37   Log-Likelihood:                -1148.4
# No. Observations:                 398   AIC:                             2301.
# Df Residuals:                     396   BIC:                             2309.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         46.3174      0.795     58.243      0.000      44.754      47.881
# ...

# %%
result.params
# Out:
# const     46.317364
# weight    -0.007677
# dtype: float64

# %%
result.rsquared
# Out:
# 0.6917929800341575

# %% [markdown]
# ## 1.2 Grafic Linear Regression

# %%
sns.set_theme(color_codes=True)

# %%
ax1=sns.regplot(data=auto,x='weight', y='mpg')
ax1.set_xlabel('Peso')
ax1.set_ylabel('MPG')
ax1.set_title('Relacion Peso-MPG')
ax1.plot()
# Out:
# []

# %%
ax2= sns.jointplot(x='weight' , y='mpg' , data=auto , kind='reg' , truncate=False , color='r', height=7)
