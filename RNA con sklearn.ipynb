# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.neural_network import MLPClassifier
import pandas as pd

# %%
data = sns.load_dataset('iris')
data.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
train , test = train_test_split(data,test_size=0.4,stratify=data['species']
                                , random_state=42)

# %%
X_train = train[['sepal_length','sepal_width','petal_length','petal_width']]
y_train = train['species']

X_test = test[['sepal_length','sepal_width','petal_length','petal_width']]
y_test = test['species']

# %%
mlp = MLPClassifier(hidden_layer_sizes=10,solver='sgd',learning_rate_init=0.1,max_iter=500)

# %%
#Codificar la variable
from sklearn.preprocessing import LabelEncoder

codificador = LabelEncoder()

# %%
data['species'] = codificador.fit_transform(data['species'])
species = pd.DataFrame({'species':['setosa','versicolor','virginica']})

# %%
data.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width  species
# 0           5.1          3.5           1.4          0.2        0
# 1           4.9          3.0           1.4          0.2        0
# 2           4.7          3.2           1.3          0.2        0
# 3           4.6          3.1           1.5          0.2        0
# 4           5.0          3.6           1.4          0.2        0

# %%
data.tail()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width  species
# 145           6.7          3.0           5.2          2.3        2
# 146           6.3          2.5           5.0          1.9        2
# 147           6.5          3.0           5.2          2.0        2
# 148           6.2          3.4           5.4          2.3        2
# 149           5.9          3.0           5.1          1.8        2

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc = StandardScaler()

# %%
noescalado = X_train
X_train_array = sc.fit_transform(X_train.values)

# %%
X_train = pd.DataFrame(X_train_array, index=X_train.index,
                        columns=X_train.columns)

# %%
X_train
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 130      1.788755    -0.565424      1.301460     0.905373
# 6       -1.480036     0.717471     -1.350359    -1.173952
# 94      -0.312611    -0.779240      0.229448     0.125626
# 96      -0.195868    -0.351608      0.229448     0.125626
# 26      -1.013066     0.717471     -1.237516    -1.043995
# ..            ...          ...           ...          ...
# 37      -1.129808     1.145103     -1.350359    -1.433868
# 89      -0.429353    -1.206872      0.116605     0.125626
# 33      -0.429353     2.427999     -1.350359    -1.303910
# 99      -0.195868    -0.565424      0.173027     0.125626
# 3       -1.480036     0.076023     -1.293937    -1.303910
#
# [90 rows x 4 columns]

# %%
X_test_array = sc.fit_transform(X_test.values)
X_test = pd.DataFrame(X_test_array, index=X_test.index,
                        columns=X_test.columns)

# %%
X_test
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 40      -1.041441     1.196764     -1.383432    -1.199540
# 61       0.120497    -0.123196      0.284740     0.411783
# 18      -0.137711     1.988740     -1.153339    -1.199540
# 49      -1.041441     0.668780     -1.325908    -1.333817
# 106     -1.170545    -1.443157      0.457309     0.680336
# 20      -0.525024     0.932772     -1.153339    -1.333817
# 69      -0.266815    -1.443157      0.112170    -0.125325
# 93      -1.041441    -1.971141     -0.232969    -0.259602
# 141      1.411540     0.140796      0.802448     1.485998
# 104      0.895123    -0.123196      1.205110     1.351721
# 85       0.249602     0.932772      0.457309     0.546059
# 78       0.249602    -0.387188      0.457309     0.411783
# 133      0.636914    -0.651180      0.802448     0.411783
# 127      0.378706    -0.123196      0.687402     0.814613
# 2       -1.428753     0.404788     -1.383432    -1.333817
# 1       -1.170545    -0.123196     -1.325908    -1.333817
# 35      -1.041441     0.404788     -1.440955    -1.333817
# 42      -1.816066     0.404788     -1.383432    -1.333817
# 148      0.507810     0.932772      0.975017     1.485998
# 122      2.444373    -0.651180      1.722818     1.083167
# 77       1.153331    -0.123196      0.744925     0.680336
# 98      -0.912337    -1.443157     -0.405538    -0.125325
# 107      1.927956    -0.387188      1.492726     0.814613
# 111      0.766018    -0.915172      0.917494     0.948890
# 51       0.766018     0.404788      0.457309     0.411783
# 132      0.766018    -0.651180      1.090064     1.351721
# 116      0.895123    -0.123196      1.032540     0.814613
# 36      -0.395920     1.196764     -1.383432    -1.333817
# 123      0.636914    -0.915172      0.687402     0.814613
# 23      -0.912337     0.668780     -1.153339    -0.930987
# 145      1.153331    -0.123196      0.859971     1.485998
# 97       0.507810    -0.387188      0.342263     0.143229
# 134      0.378706    -1.179165      1.090064     0.277506
# 21      -0.912337     1.724748     -1.268385    -1.065264
# 22      -1.557858     1.460756     -1.556001    -1.333817
# 108      1.153331    -1.443157      1.205110     0.814613
# 11      -1.299649     0.932772     -1.210862    -1.333817
# 55      -0.137711    -0.651180      0.457309     0.143229
# 7       -1.041441     0.932772     -1.268385    -1.333817
# 147      0.895123    -0.123196      0.859971     1.083167
# 56       0.636914     0.668780      0.572355     0.546059
# 144      1.153331     0.668780      1.147587     1.754552
# 66      -0.266815    -0.123196      0.457309     0.411783
# 63       0.378706    -0.387188      0.572355     0.277506
# 67      -0.008607    -0.915172      0.227216    -0.259602
# 87       0.636914    -1.971141      0.399786     0.143229
# 53      -0.395920    -1.971141      0.169693     0.143229
# 10      -0.525024     1.724748     -1.268385    -1.333817
# 29      -1.428753     0.404788     -1.210862    -1.333817
# 138      0.249602    -0.123196      0.629878     0.814613
# 14      -0.008607     2.516724     -1.440955    -1.333817
# 75       1.024227    -0.123196      0.399786     0.277506
# 58       1.024227    -0.387188      0.514832     0.143229
# 57      -1.170545    -1.707149     -0.232969    -0.259602
# 102      1.669748    -0.123196      1.262633     1.217444
# 140      1.153331     0.140796      1.090064     1.620275
# 43      -1.041441     1.196764     -1.210862    -0.796710
# 84      -0.525024    -0.123196      0.457309     0.411783
# 38      -1.816066    -0.123196     -1.383432    -1.333817
# 28      -0.783232     0.932772     -1.325908    -1.333817

# %%
mlp.fit(X_train,y_train)
# Out:
# MLPClassifier(hidden_layer_sizes=10, learning_rate_init=0.1, max_iter=500,
#               solver='sgd')

# %%
from sklearn.metrics import accuracy_score

# %%
mlp.score(X_train,y_train)
# Out:
# 0.9888888888888889

# %%
mlp.score(X_test,y_test)
# Out:
# 0.95

# %%
prediccion_train = mlp.predict(X_train)
prediccion_test = mlp.predict(X_test)

# %%
train_punteo = accuracy_score(prediccion_train,y_train)
train_punteo

# %%
test_punteo = accuracy_score(prediccion_test,y_test)
test_punteo
# Out:
# 0.95
